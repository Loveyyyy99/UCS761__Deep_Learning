# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("multiple_linear_regression_dataset.csv")

# %%
print(data.head())
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
print(data.columns)
# Out:
# Index(['age', 'experience', 'income'], dtype='object')

# %%
X = data[["experience","age"]]
y = data["income"]

# %%
n_features = X.shape[1]
w = np.zeros(n_features)
b =0.0

# %%
def predict(X, w, b):
    return X.dot(w) + b

# %%
def mean_squared_error(y, y_hat):
    loss = ((y_hat - y) **2).mean()
    return loss

# %%
def compute_gradients(X, y, y_hat):

    N =len(y)
    dw = (2 / N) * X.T.dot(y_hat - y)
    db = (2 / N) * (y_hat - y).sum()
    return dw, db

# %%
def update_parameters(w, b, dw, db, lr):
    w = w - lr * dw
    b = b - lr * db
    return w, b

# %%
lr = 0.0001
epochs = 1000

for epoch in range(epochs):
    y_hat = predict(X, w, b)
    loss = mean_squared_error(y, y_hat)
    dw, db = compute_gradients(X, y, y_hat)
    w, b = update_parameters(w, b, dw, db, lr)

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss}")
# Out:
# Epoch 0, Loss: 1727049635.0
# Epoch 100, Loss: 66491868.553113505
# Epoch 200, Loss: 61752567.2011901
# Epoch 300, Loss: 58616531.07847047
# Epoch 400, Loss: 56528801.53951119
# Epoch 500, Loss: 55126542.02946699
# Epoch 600, Loss: 54172526.948857024
# Epoch 700, Loss: 53511656.14292053
# Epoch 800, Loss: 53042523.72795741
# Epoch 900, Loss: 52698829.56325033

# %%
print("Final Weights:", w)
print("Final Bias:", b)

new_candidate = np.array([4.5, 68])
predicted_salary = new_candidate.dot(w) + b
print("Predicted Salary:", predicted_salary)
# Out:
# Final Weights: experience    1371.034304
# age            764.754059
# dtype: float64
# Final Bias: 321.736411744725
# Predicted Salary: 58494.66680654775
